# %%
import altair
import pandas as pd

# %%
data = pd.read_csv('modules.csv', delimiter=',')
print(data.head())
# Out:
#   PHAS1202 PHAS1224 PHAS1228  PHAS1240  PHAS1241 PHAS1245 PHAS1246 PHAS1247
# 0       84       64       79        79      71.0       77       95       65
# 1       40       24       38        70      61.0       31       54       19
# 2       58       54       67        59      77.0       70       80       70
# 3       DA       DA       DA        52      72.0       DA       DA       DA
# 4       62       46       73        36      71.0       60       79       48

# %%
Chart(data).mark_bar().encode(
    x=X('PHAS1202:Q', bin=True),
    y=Y('count(*):Q'),
    color='count(*):Q',
)
# Out:
# <div class="vega-embed" id="c78ec62c-a958-4a80-b756-1a2732e09a69"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
Chart(data).mark_bar().encode(
    x=X('PHAS1224:Q', bin=True),
    y=Y('count(*):Q'),
    color='count(*):Q',
)
# Out:
# <div class="vega-embed" id="32c0e898-851e-4dc3-8ca9-0e3fad3c9b88"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
Chart(data).mark_bar().encode(
    x=X('PHAS1228:Q', bin=True),
    y=Y('count(*):Q'),
    color='count(*):Q',
)
# Out:
# <div class="vega-embed" id="e9ed6c80-9160-48eb-ad3a-e0751513ad95"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
Chart(data).mark_bar().encode(
    x=X('PHAS1240:Q', bin=True),
    y=Y('count(*):Q'),
    color='count(*):Q',
)
# Out:
# <div class="vega-embed" id="066f9721-2505-4287-a8df-d118db24a990"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
Chart(data).mark_bar().encode(
    x=X('PHAS1241:Q', bin=True),
    y=Y('count(*):Q'),
    color='count(*):Q',
)
# Out:
# <div class="vega-embed" id="7fb01bdb-3030-4fa9-8879-21522e414f1d"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
Chart(data).mark_bar().encode(
    x=X('PHAS1245:Q', bin=True),
    y=Y('count(*):Q'),
    color='count(*):Q',
)
# Out:
# <div class="vega-embed" id="5251e412-95e3-4600-a43a-94a5d563493a"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
Chart(data).mark_bar().encode(
    x=X('PHAS1246:Q', bin=True),
    y=Y('count(*):Q'),
    color='count(*):Q',
)
# Out:
# <div class="vega-embed" id="3cf30fdd-6b4c-422b-a0c9-23e1d6f2dc14"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
Chart(data).mark_bar().encode(
    x=X('PHAS1247:Q', bin=True),
    y=Y('count(*):Q'),
    color='count(*):Q',
)
# Out:
# <div class="vega-embed" id="11eea4b8-f0e3-45e2-a289-6dadfa375481"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>
